# %%
#test new print tic tac toe board
def print_tic_tac_toe_list(tic_tac_toe_list):
    print('_________________', '\n')
    print('| ' , tic_tac_toe_list[0][0] , ' | ' , tic_tac_toe_list[0][1] , '| ' , tic_tac_toe_list[0][2] , '|','\n')
    print('| ' , tic_tac_toe_list[1][0] , ' | ' , tic_tac_toe_list[1][1] , '| ' , tic_tac_toe_list[1][2] , '|','\n')
    print('| ' , tic_tac_toe_list[2][0] , ' | ' , tic_tac_toe_list[2][1] , '| ' , tic_tac_toe_list[2][2] , '|')
    print('_________________')

# %%
def assign_position(tic_tac_toe_list, X_O_position, player1, player2):
    #Assign X to position in grid selected by player1
    if X_O_position == 1 and player1 == True:
        tic_tac_toe_list[0][0] = 'X'
        player1 = False
    elif X_O_position == 2 and player1 == True:
        tic_tac_toe_list[0][1] = 'X'  
        player1 = False
    elif X_O_position == 3 and player1 == True:
        tic_tac_toe_list[0][2] = 'X'   
        player1 = False
    elif X_O_position == 4 and player1 == True:
        tic_tac_toe_list[1][0] = 'X'  
        player1 = False
    elif X_O_position == 5 and player1 == True:
        tic_tac_toe_list[1][1] = 'X'  
        player1 = False
    elif X_O_position == 6 and player1 == True:
        tic_tac_toe_list[1][2] = 'X'  
        player1 = False
    elif X_O_position == 7 and player1 == True:
        tic_tac_toe_list[2][0] = 'X'  
        player1 = False
    elif X_O_position == 8 and player1 == True:
        tic_tac_toe_list[2][1] = 'X'  
        player1 = False
    elif X_O_position == 9 and player1 == True:
        tic_tac_toe_list[2][2] = 'X'
        player1 = False
        
        
    #Assign O to position in grid selected by player2
    if X_O_position == 1 and player2 == True:
        tic_tac_toe_list[0][0] = 'O'  
        player2 = False
    elif X_O_position == 2 and player2 == True:
        tic_tac_toe_list[0][1] = 'O'  
        player2 = False
    elif X_O_position == 3 and player2 == True:
        tic_tac_toe_list[0][2] = 'O' 
        player2 = False
    elif X_O_position == 4 and player2 == True:
        tic_tac_toe_list[1][0] = 'O'   
        player2 = False
    elif X_O_position == 5 and player2 == True:
        tic_tac_toe_list[1][1] = 'O'   
        player2 = False
    elif X_O_position == 6 and player2 == True:
        tic_tac_toe_list[1][2] = 'O'  
        player2 = False
    elif X_O_position == 7 and player2 == True:
        tic_tac_toe_list[2][0] = 'O'  
        player2 = False
    elif X_O_position == 8 and player2 == True:
        tic_tac_toe_list[2][1] = 'O'  
        player2 = False
    elif X_O_position == 9 and player2 == True:
        tic_tac_toe_list[2][2] = 'O'
        player = False

# %%
def who_wins(tic_tac_toe_list):
    
    #Does player1 win?
    if tic_tac_toe_list[0][0] == 'X' and tic_tac_toe_list[0][1] == 'X' and tic_tac_toe_list[0][2] == 'X':
        return True
    elif tic_tac_toe_list[1][0] == 'X' and tic_tac_toe_list[1][1] == 'X' and tic_tac_toe_list[1][2] == 'X':
        return True
    elif tic_tac_toe_list[2][0] == 'X' and tic_tac_toe_list[2][1] == 'X' and tic_tac_toe_list[2][2] == 'X':
        return True
    elif tic_tac_toe_list[0][0] == 'X' and tic_tac_toe_list[1][0] == 'X' and tic_tac_toe_list[2][0] == 'X':
        return True
    elif tic_tac_toe_list[0][1] == 'X' and tic_tac_toe_list[1][1] == 'X' and tic_tac_toe_list[2][1] == 'X':
        return True
    elif tic_tac_toe_list[0][2] == 'X' and tic_tac_toe_list[1][2] == 'X' and tic_tac_toe_list[2][2] == 'X':
        return True
    elif tic_tac_toe_list[0][0] == 'X' and tic_tac_toe_list[1][1] == 'X' and tic_tac_toe_list[2][2] == 'X':
        return True
    elif tic_tac_toe_list[2][0] == 'X' and tic_tac_toe_list[1][1] == 'X' and tic_tac_toe_list[0][2] == 'X':
        return True
        
    #Does player2 win? USE THE LETTER O NOT THE NUMBER 0
    if tic_tac_toe_list[0][0] == 'O' and tic_tac_toe_list[0][1] == 'O' and tic_tac_toe_list[0][2] == 'O':
        return True
    elif tic_tac_toe_list[1][0] == 'O' and tic_tac_toe_list[1][1] == 'O' and tic_tac_toe_list[1][2] == 'O':
        return True
    elif tic_tac_toe_list[2][0] == 'O' and tic_tac_toe_list[2][1] == 'O' and tic_tac_toe_list[2][2] == 'O':
        return True
    elif tic_tac_toe_list[0][0] == 'O' and tic_tac_toe_list[1][0] == 'O' and tic_tac_toe_list[2][0] == 'O':
        return True
    elif tic_tac_toe_list[0][1] == 'O' and tic_tac_toe_list[1][1] == 'O' and tic_tac_toe_list[2][1] == 'O':
        return True
    elif tic_tac_toe_list[0][2] == 'O' and tic_tac_toe_list[1][2] == 'O' and tic_tac_toe_list[2][2] == 'O':
        return True
    elif tic_tac_toe_list[0][0] == 'O' and tic_tac_toe_list[1][1] == 'O' and tic_tac_toe_list[2][2] == 'O':
        return True
    elif tic_tac_toe_list[2][0] == 'O' and tic_tac_toe_list[1][1] == 'O' and tic_tac_toe_list[0][2] == 'O':
        return True

# %%
#Check if board is full
def check_if_board_full(tic_tac_toe_list):
    return((tic_tac_toe_list[0][0] == 'O' or tic_tac_toe_list[0][0] == 'X') and
           (tic_tac_toe_list[0][1] == 'O' or tic_tac_toe_list[0][1] == 'X') and
           (tic_tac_toe_list[0][2] == 'O' or tic_tac_toe_list[0][2] == 'X') and
           (tic_tac_toe_list[1][0] == 'O' or tic_tac_toe_list[1][0] == 'X') and
           (tic_tac_toe_list[1][1] == 'O' or tic_tac_toe_list[1][1] == 'X') and
           (tic_tac_toe_list[1][2] == 'O' or tic_tac_toe_list[1][2] == 'X') and
           (tic_tac_toe_list[2][0] == 'O' or tic_tac_toe_list[2][0] == 'X') and
           (tic_tac_toe_list[2][1] == 'O' or tic_tac_toe_list[2][1] == 'X') and
           (tic_tac_toe_list[2][2] == 'O' or tic_tac_toe_list[2][2] == 'X'))

# %%
import random
tic_tac_toe_list = [[1,2,3], [4,5,6], [7,8,9]]
bool_play_game = True
bool_new_game = True
bool_start_game = True
starting_player = 6
X_O_position = 0
user_input = ''
choice = ''


while bool_play_game == True:

    choice = input('Do you want to play Tic Tac Toe? Select Y or N: ')

    #Choose player to go first using random number generator 1 for player1 and 0 for player 2
    starting_player = random.randint(0,1)

    #while loop to continue game if player wishes to continue play
    while bool_new_game == True:

            if choice == 'Y' or choice == 'N':
                if choice == 'Y':

                    print_tic_tac_toe_list(tic_tac_toe_list)

                    if starting_player == 1:
                        user_input = input('Player One select a position (1-9): ')
                        
                        X_O_position = int(user_input)
                        
                        if X_O_position in range(1,10):
                            
                            player1 = True
                            player2 = False
                            if check_if_board_full(tic_tac_toe_list) == True:
                                print('No more moves and no winner. Game is a tie.')
                                break
                            assign_position(tic_tac_toe_list, X_O_position, player1, player2)    
                            print('Tic tac toe after position assignment is: ')
                            
                            if who_wins(tic_tac_toe_list) == True:
                                print('Player One wins the game.')
                                tic_tac_toe_list = [[1,2,3], [4,5,6], [7,8,9]]
                                break
                        else:
                            print('Please select a position (1-9): ')

                    if starting_player == 0:
                        user_input = input('Player Two select a position (1-9): ')
                        
                        X_O_position = int(user_input)
                        
                        if X_O_position in range(1,10):
                            
                            if check_if_board_full(tic_tac_toe_list) == True:
                                print('No more moves and no winner. Game is a tie.')
                                break
                            player1 = False
                            player2 = True
                            assign_position(tic_tac_toe_list, X_O_position, player1, player2)    
                            print('Tic tac toe after position assignment is: ')
                            
                            if who_wins(tic_tac_toe_list) == True:
                                print('Player Two wins the game.')
                                tic_tac_toe_list = [[1,2,3], [4,5,6], [7,8,9]]
                                break
                            else:
                                print('No winner yet.')
                        else:
                            print('Please select a position (1-9): ')  

                    if starting_player == 1:
                        starting_player = 0
                    elif starting_player == 0:
                        starting_player = 1

                if choice == 'N':
                    bool_answer = False
                    print('OK no game')
                    break
            else:
                print('Sorry you must select either Y or N')
    if choice == 'N':
        break
# Out:
# Do you want to play Tic Tac Toe? Select Y or N: Y
# _________________
#
# |  1  |  2 |  3 |
#
# |  4  |  5 |  6 |
#
# |  7  |  8 |  9 |
# _________________
# Player Two select a position (1-9): 1
# Tic tac toe after position assignment is:
# No winner yet.
# _________________
#
# |  O  |  2 |  3 |
#
# |  4  |  5 |  6 |
#
# |  7  |  8 |  9 |
# _________________
# Player One select a position (1-9): 7
# Tic tac toe after position assignment is:
# _________________
#
# |  O  |  2 |  3 |
#
# |  4  |  5 |  6 |
#
# |  X  |  8 |  9 |
# _________________
# Player Two select a position (1-9): 5
# Tic tac toe after position assignment is:
# No winner yet.
# _________________
#
# |  O  |  2 |  3 |
#
# |  4  |  O |  6 |
#
# |  X  |  8 |  9 |
# _________________
# Player One select a position (1-9): 6
# Tic tac toe after position assignment is:
# _________________
#
# |  O  |  2 |  3 |
#
# |  4  |  O |  X |
#
# |  X  |  8 |  9 |
# _________________
# Player Two select a position (1-9): 9
# ...
