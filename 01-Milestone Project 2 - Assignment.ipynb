# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Milestone Project 2 - Blackjack Game
# In this milestone project you will be creating a Complete BlackJack Card Game in Python.
#
# Here are the requirements:
#
# * You need to create a simple text-based [BlackJack](https://en.wikipedia.org/wiki/Blackjack) game
# * The game needs to have one player versus an automated dealer.
# * The player can stand or hit.
# * The player must be able to pick their betting amount.
# * You need to keep track of the player's total money.
# * You need to alert the player of wins, losses, or busts, etc...
#
# And most importantly:
#
# * **You must use OOP and classes in some portion of your game. You can not just use functions in your game. Use classes to help you define the Deck and the Player's hand. There are many right ways to do this, so explore it well!**
#
#
# Feel free to expand this game. Try including multiple players. Try adding in Double-Down and card splits! Remember to you are free to use any resources you want and as always:
#
# # HAVE FUN!

# %%
import random 
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':10, 'Queen':10, 'King':10, 'Ace':11}
#money player has
playerMoney = 0
#player's cards
playerCards = []
#dealer's cards
dealerCards = []
#boolean for outer most while loop for the game
boolNewGame = True
#boolean for while loop while game being played
boolGameOn = True
#boolean for inner while loop for player to receive more cards
boolPlayerOn = True
#boolean for inner while loop for dealer to receive more cards
boolDealerOn = True
playerCardsValue = 0
dealerCardsValue = 0
playerAnswer = ''
dealerAnswer = ''
playersMoney = 0
playersBet = 0

# %%
class Card:
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        return self.rank + ' of ' + self.suit
    
class Deck:
    
    def __init__(self):
        # Note this only happens once upon creation of a new Deck
        self.all_cards = [] 
        for suit in suits:
            for rank in ranks:
                # This assumes the Card class has already been defined!
                self.all_cards.append(Card(suit,rank))
                
    def shuffle(self):
        # Note this doesn't return anything
        random.shuffle(self.all_cards)
        
    def deal_one(self):
        # Note we remove one card from the list of all_cards
        return self.all_cards.pop()

# %%
def playerPoints(playerCards):
    
    playerPoints = 0
    
    for playerCard in playerCards:
        #prints out the cards held by the player
        print(f' {playerCard} \n')
        
        playerPoints += playerCard.value
        print(f' playerPoints after addition is: {playerPoints}.\n')
        
    return playerPoints

# %%
def dealerPoints(dealerCards):
    
    dealerPoints = 0
    
    for dealerCard in dealerCards:
        #prints out the cards held by the player
        print(f' {dealerCard} \n')
        
        dealerPoints += dealerCard.value
        print(f' dealerPoints after addition is: {dealerPoints}.\n')
        
    return dealerPoints

# %%
class Dealer:
    
    def __init__(self,dealerName, dealerDeck,playerName,playerCards,dealerCards):
        self.dealerName = dealerName
        #dealerDeck is the deck of cards
        self.dealerDeck = dealerDeck
        self.playName = playerName
        #dealerCards variable is for the cards dealt to the dealer
        self.dealerCards = dealerCards
        #playerCards variable is for the cards dealt to the player
        self.playerCards = playerCards
        
    def dealerDealsToPlayer(self):
        # Dealer deals one card from the deck to the player
        self.playerCards.append(self.dealerDeck.all_cards.pop(0))
    
    def dealerDealsToDealer(self):
        # Dealer deals one card from the deck to the dealer
        self.dealerCards.append(self.dealerDeck.all_cards.pop(0))
        
    def dealerHiddenCard(self):
        hiddenCard = ()
        
    def dealerTotal(self):
        dealerCard_total = 0
        for card in self.dealerCards:
            dealerCard_total += card.value
    
    def __str__(self):
        return f'Dealer {self.dealerName} has {len(self.dealerCards)} cards.\n The dealer total is: {dealerCard_total}.\n'

# %%
class Player:
    
    def __init__(self,playerName,playerCards):
        self.name = playerName
        self.playerCards = playerCards
        
    def playerTotal(self):
        playerCard_total = 0
        for card in self.playerCards:
            playerCard_total += card.value
            
    def playerMoney(self):
        moneyRemaining = 0
        moneyRemaining = playerMoney
        
    def playerStatus(self):
        #This will contain 'Stand' of 'Hit'
        currentStatus = ''
    
    def __str__(self):
        return f'Player {self.playerName} has {len(self.playerCards)} cards.\n {playerName} has a total of {playerCard_total}.\n'

# %%
#while loop for the entrie game
while boolNewGame == True:
    
    #while loop to check for correct input whether to play game and how much money to start game
    while True:
        answer = input('Do you want to play a game of blackjack? Answer Y or N: \n')
        
        if answer == 'Y' or answer == 'N':
            break
        else:
             print('You must answer Y or N.\n')         
    
    if answer == 'N':
        print('You answered N so no game.\n')
        break
    elif answer == 'Y':
        while True:
            try:
                playersMoney = int(input('How much money do you want to play blackjack with? '))
                print(f'playersMoney is {playersMoney}.\n')
                break
            except ValueError:
                print('That is not a valid number. Please enter an integer.')
    
    #creates instance of the Deck class
    dealerDeck = Deck()
    #shuffles the deck dealerDeck
    random.shuffle(dealerDeck.all_cards)
    playerCards = []
    #dealer's cards
    dealerCards = []
    playerCardsValue = 0
    dealerCardsValue = 0
    playersBet = 0
    #starts while loop for new game by setting boolGameOn to True
    boolGameOn = True
    boolPlayerOn = True
    boolDealerOn = True
    
    #while loop for time current game is being played   
    while boolGameOn == True:
            
            if playersMoney <= 0:
                print(f'Player loses because player out of money.  Player money is ${playersMoney}.\n')
                print('Dealer wins!')
                print('Game over!')
                boolPlayerOn = False
                boolGameOn = False
                boolDealerOn = False
                break
            
            print(f'Player now has this much money to bet: ${playersMoney}.\n')
            while True:
                try:
                    playersBet = int(input('How much do you want to bet? '))
                    break
                except:
                    print('That is not a valid number. Please enter an integer.')
            print(f'playersBet is {playersBet}.\n')
            if playersBet > playersMoney:
                print(f'You have this much money: ${playersMoney} but your bet ${playersBet}.\n')
                print('You can not bet more money than you have! So you lose!')
                boolPlayerOn = False
                boolGameOn = False
                boolDealerOn = False
                break
            
            #while loop for player in case player wants a Hit
            while boolPlayerOn == True:
                
                print(f'playerCardsValue is: {playerCardsValue}.\n')
                if playerCardsValue == 21:
                    print('playerCardsValue equals 21. Player wins.\n')
                    boolPlayerOn = False
                    boolGameOn = False
                    boolDealerOn = False
                    playersMoney += playersBet
                    break
                if playerCardsValue > 21:
                    #checks for ace and if ace found counts ace as one instead of 11
                    boolAceFound = False
                    for someCard in playerCards:
                        if someCard.value == 11:
                            boolAceFound = True
                            break
                    if boolAceFound == True:
                        playerCardsValue -= 10
                    else:
                        #ace not found in player's cards so playerCardsValue cannot be adjusted and player over 21
                        print(f'Player went over 21 because you have {playerCardsValue} points. You went Bust.\n')
                        boolPlayerOn = False
                        boolDealerOn = False
                        boolGameOn = False
                        playersMoney -= playersBet
                        break
                if playerCardsValue < 21 and playerAnswer != 'Stand':
                    while True:
                        playerAnswer = input('What does Player want to do?  Answer Stand or Hit: \n')
                        if playerAnswer == 'Stand' or playerAnswer == 'Hit':
                            break
                        else:
                            print('You need to answer either Stand or Hit.\n')
                if playerAnswer == 'Stand':
                    print(f'You answered {playerAnswer} so you get no more cards.\n')
                    boolPlayerOn = False
                    break
                if playerAnswer == 'Hit':
                    print('You get another card.\n')
                    playerAnswer = ''
                    playerCards.append(dealerDeck.all_cards.pop(0))
                 
                    playerCardsValue = playerPoints(playerCards)
                   
  
            #while loop for dealer in case dealer wants a Hit
            while boolDealerOn == True:
                
                if dealerCardsValue == 21:
                    print('dealerCardsValue equals 21.\n')
                    print('Dealer wins!')
                    playersMoney -= playersBet
                    boolPlayerOn = False
                    boolGameOn = False
                    boolDealerOn = False
                    break
                if dealerCardsValue > 21:
                    #checks for ace and if ace found counts ace as one instead of 11
                    boolAceFound = False
                    for someCard in dealerCards:
                        if someCard.value == 11:
                            boolAceFound = True
                            break
                    if boolAceFound == True:
                        dealerCardsValue -= 10
                    else:
                        #ace not found in dealer's cards so dealerCardsValue cannot be adjusted and dealer over 21
                        print(f'Dealer went over 21 because you have {dealerCardsValue} points. You went Bust.\n')
                        boolPlayerOn = False
                        boolDealerOn = False
                        boolGameOn = False
                        playersMoney += playersBet
                        break
                if  dealerCardsValue < 21 or dealerAnswer != 'Stand':
                    #if dealerCardsValue >= 17:
                        #dealerAnswer = 'Stand'
                    #else:
                        #dealerAnswer = 'Hit'
                    #break
                    while True:
                        dealerAnswer = input('What does Dealer want to do? Answer Stand or Hit: \n')
                        if dealerAnswer == 'Stand' or dealerAnswer == 'Hit':
                            break
                        else:
                            print('You need to answer either Stand or Hit.\n')
                if dealerAnswer == 'Stand':
                    print(f'You answered {dealerAnswer} so you get no more cards.\n')
                    boolDealerOn = False
                    break
                elif dealerAnswer == 'Hit':
                        print('You get another card.\n')
                        dealerAnswer = ''
                        dealerCards.append(dealerDeck.all_cards.pop(0))
                        dealerCardsValue = dealerPoints(dealerCards)
                
            if playerAnswer == 'Stand' and dealerAnswer == 'Stand':
                print(f'Both players Stand. Player has {playerCardsValue} and Dealer has {dealerCardsValue}.\n')
                if playerCardsValue > dealerCardsValue:
                    boolGameOn = False
                    print('Player wins. Game over.\n')
                    playersMoney += playersBet
                    print(f'playersMoney after WIN is {playersMoney}.\n')
                    playerAnswer = ''
                    dealerAnswer = ''
                    break
                elif dealerCardsValue > playerCardsValue:
                        print('Dealer wins. Game over.\n')
                        boolGameOn = False
                        playersMoney -= playersBet
                        print(f'playersMoney after LOSS is {playersMoney}.\n')
                        playerAnswer = ''
                        dealerAnswer = ''
                        break
                elif dealerCardsValue == playerCardsValue:
                        print('Players are TIED. No one wins. Game over.')
                        print(f'playersMoney does not change and is {playersMoney}.\n')
                        playerAnswer = ''
                        dealerAnswer = ''
                        boolGameOn = False
